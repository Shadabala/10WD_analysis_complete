# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users\Ducat\Desktop\waves.csv")

# %%
df.corr()
# Out:
#                             SOURCE_ID   WAVE_ID      YEAR     MONTH       DAY  \
# SOURCE_ID                    1.000000  0.614917  0.396351 -0.381868 -0.102761
# WAVE_ID                      0.614917  1.000000  0.234197 -0.111947  0.000934
# YEAR                         0.396351  0.234197  1.000000 -0.098827 -0.006509
# MONTH                       -0.381868 -0.111947 -0.098827  1.000000  0.267048
# DAY                         -0.102761  0.000934 -0.006509  0.267048  1.000000
# REGION_CODE                  0.170880 -0.016982  0.188055 -0.357235 -0.223277
# LATITUDE                     0.008749 -0.079340 -0.057612 -0.169829 -0.218725
# LONGITUDE                    0.086743  0.157008  0.025649 -0.044499 -0.115514
# DISTANCE_FROM_SOURCE        -0.134180 -0.117692  0.043730 -0.015926  0.097631
# TRAVEL_TIME_HOURS            0.146584  0.055545  0.154532  0.032538  0.198236
# TRAVEL_TIME_MINUTES          0.021516  0.010417  0.028424 -0.021767  0.000448
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sn

# %%
plt.figure(figsize=(15,15))
sn.heatmap(df.corr(),annot=df.corr(),fmt='.2f')
plt.show()
